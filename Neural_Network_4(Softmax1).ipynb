# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
tf.autograph.set_verbosity(0)

# %%
def my_softmax(z):
    ez = np.exp(z)              #element-wise exponenial
    sm = ez/np.sum(ez)
    return(sm)

# %%
#synthetic datapoints
from sklearn.datasets import make_blobs
centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]]
X_train, y_train = make_blobs(n_samples=2000, centers=centers, cluster_std=1.0,random_state=30)

# %%
from tensorflow.keras.losses import SparseCategoricalCrossentropy
model=Sequential([
    Dense(units=25,activation='relu'),
    Dense(units=15,activation='relu'),
    Dense(units=4,activation='softmax')
])
model.compile(
    loss=SparseCategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(0.001)
)

model.fit(X_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.9880
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5674
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2708
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1220
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0763
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0583
# Epoch 7/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487
# Epoch 8/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0429
# Epoch 9/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0385
# Epoch 10/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0355

# %%
prediction = model.predict(X_train)
#show what is prediction for first two training examples 
print(prediction[:2])
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [[2.0334704e-04 1.4505913e-03 9.8403519e-01 1.4310869e-02]
#  [9.9285525e-01 6.9973599e-03 1.1537769e-04 3.2020838e-05]]
