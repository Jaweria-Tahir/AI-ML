# %%
import numpy as np

#BASICS OF NUMPY
# a = np.array([2.,3,4,5])
# b = np.zeros(3)
# c = np.random.random_sample((7,))
# d = np.arange(4.)
# e = np.random.rand(4)
# print(a)
# print(f'shape:{b.shape}  , datatype:{b.dtype}')

#operations

#indexing
# a = np.arange(10)
# try:
#     print(a[10])
# except Exception as e:
#     print(e)

#slicing
# a= np.arange(10)
# print(a[:7])

# #single vector opeartions
# a= np.arange(10)
# b = np.mean(a)
# print(b)

#opeartion of vectors with vectors
# a = np.array([ 1, 2, 3, 4])
# b = np.array([-1,-2, 3, 4])
# print(f"Binary operators work element wise: {a + b}")

#try a mismatched vector operation
# c = np.array([1, 2])
# try:
#     d = a + c
# except Exception as e:
#     print("The error message you'll see is:")
#     print(e)

#opeartion of vectors with scalars
# a = np.array([1, 2, 3, 4])
# b = 5 * a 
# print(f"b = 5 * a : {b}")

#scalar product 1
# a = np.array([1,2,3])
# b = np.array([4,5,6])
# c = np.dot(a,b)
# print(c)

# scalar product 2
# def dot_product_loop(a,b):
#     m = a.shape[0]
#     sum=0
#     for i in range(m):
#         x=a[i]*b[i]
#         sum+=x


# #time difference between loop vs numpy dot routine
# import time
# np.random.seed(1)
# a=np.random.rand(1000)
# b=np.random.rand(1000)

# tic = time.time()  # capture start time
# c = np.dot(a, b)
# toc = time.time()  # capture end time
# print(1000*(toc-tic))

# tic = time.time()  # capture start time
# c = dot_product_loop(a, b)
# toc = time.time()  # capture end time
# print(1000*(toc-tic))

#feature and weight 
# X = np.array([[1],[2],[3],[4]])
# w = np.array([2])
# c = np.dot(X[1], w)

# print(f"X[1] has shape {X[1].shape}")
# print(f"w has shape {w.shape}")
# print(f"c has shape {c}")

#MATRICES
# a = np.random.random((1, 5)) 
# print(a)

# NumPy routines which allocate memory and fill with user specified values
# a = np.array([[5], [4], [3]]);   print(f" a shape = {a.shape}, np.array: a = {a}")
# a = np.array([[5],   # One can also
#               [4],   # separate values
#               [3]]); #into separate rows
# print(f" a shape = {a.shape}, np.array: a = {a}")

#creating matrices using reshape
# a = np.arange(8).reshape(-1, 2)
# print(a)

# #slicing the matrices
# a = np.arange(20).reshape(-1, 10)
# print(a[:,1:7])
# Out:
# [[ 1  2  3  4  5  6]
#  [11 12 13 14 15 16]]
