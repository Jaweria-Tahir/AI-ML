# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documents = [
    "I love dress",
    "I love shirt",
    "I hate dress"
]

# %%
vectorizer = TfidfVectorizer()
transformed_data = vectorizer.fit_transform(documents)
print(vectorizer.vocabulary_)
# Out:
# {'love': 2, 'dress': 0, 'shirt': 3, 'hate': 1}

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['dress', 'hate', 'love', 'shirt'], dtype=object)

# %%
print(transformed_data.toarray())
# Out:
# [[0.70710678 0.         0.70710678 0.        ]
#  [0.         0.         0.60534851 0.79596054]
#  [0.60534851 0.79596054 0.         0.        ]]
